# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 'truetype'
fontProperties = {'family': 'serif', 'serif': ['Helvetica'], 'weight': 'normal', 'size': 12}
plt.rc('font', **fontProperties)
from matplotlib import gridspec
import matplotlib.pyplot as plt 
import dxchange
# %matplotlib inline

# %%
save_folder = "paper_figs"

# %% [markdown]
# # Effect of PCA analysis on log(Intensity)

# %%
cell_PCA_folder = "cell/PCA_ptycho_recon"
cell_log_PCA_folder = "cell/log2_PCA_ptycho_recon"

fig0 = plt.figure(figsize=(13.5,13))
gs0 = gridspec.GridSpec(nrows=4, ncols=5, width_ratios=[5,5,0.5,5,5]) 
gs0.update(wspace=0.005, hspace=0.005)

nei_ls = ['nei4000', 'nei3000', 'nei2000', 'nei1000']
for i in range(4):
    src_folder = os.path.join(cell_PCA_folder, 'n2e7_'+nei_ls[i])
    image = dxchange.reader.read_tiff(os.path.join(src_folder, 'delta_ds_1.tiff'))
    image = image[:,:,0]
    fig0_ax0 = fig0.add_subplot(gs0[i,0])
    fig0_ax0.axis('off')
    if i == 0:
        fig0_ax0.text(0.35, 1.05, 'PCA', transform=fig0_ax0.transAxes, color='#011FFF', fontsize=20, weight="bold")
        fig0_ax0.text(0.03, 0.90, f"S'={nei_ls[i][3:]}", transform=fig0_ax0.transAxes, color='#F7FF0F', fontsize=16)
    else:
        fig0_ax0.text(0.03, 0.90, f"{nei_ls[i][3:]}", transform=fig0_ax0.transAxes, color='#F7FF0F', fontsize=16)
    pos = fig0_ax0.imshow(image, cmap='bone', interpolation='none', extent=[0, image.shape[1], 0, image.shape[0]])

for i in range(4):
    src_folder = os.path.join(cell_log_PCA_folder, 'n2e7_'+nei_ls[i])
    image = dxchange.reader.read_tiff(os.path.join(src_folder, 'delta_ds_1.tiff'))
    image = image[:,:,0]
    fig0_ax0 = fig0.add_subplot(gs0[i,1])
    fig0_ax0.axis('off')
    if i == 0:
        fig0_ax0.text(0.25, 1.05, 'log PCA', transform=fig0_ax0.transAxes, color='#FF0101', fontsize=20, weight="bold")
    pos = fig0_ax0.imshow(image, cmap='bone', interpolation='none', extent=[0, image.shape[1], 0, image.shape[0]])    
    
    
nei_ls = ['nei500', 'nei100', 'nei50', 'nei10']
for i in range(4):
    src_folder = os.path.join(cell_PCA_folder, 'n2e7_'+nei_ls[i])
    image = dxchange.reader.read_tiff(os.path.join(src_folder, 'delta_ds_1.tiff'))
    image = image[:,:,0]
    fig0_ax0 = fig0.add_subplot(gs0[i,3])
    fig0_ax0.axis('off')
    if i == 0:
        fig0_ax0.text(0.35, 1.05, 'PCA', transform=fig0_ax0.transAxes, color='#011FFF', fontsize=20, weight="bold")
        fig0_ax0.text(0.03, 0.90, f"S'={nei_ls[i][3:]}", transform=fig0_ax0.transAxes, color='#F7FF0F', fontsize=16)
    else:
        fig0_ax0.text(0.03, 0.90, f"{nei_ls[i][3:]}", transform=fig0_ax0.transAxes, color='#F7FF0F', fontsize=16)
    pos = fig0_ax0.imshow(image, cmap='bone', interpolation='none', extent=[0, image.shape[1], 0, image.shape[0]])
    
for i in range(4):
    src_folder = os.path.join(cell_log_PCA_folder, 'n2e7_'+nei_ls[i])
    image = dxchange.reader.read_tiff(os.path.join(src_folder, 'delta_ds_1.tiff'))
    image = image[:,:,0]
    fig0_ax0 = fig0.add_subplot(gs0[i,4])
    fig0_ax0.axis('off')
    if i == 0:
        fig0_ax0.text(0.25, 1.05, 'log PCA', transform=fig0_ax0.transAxes, color='#FF0101', fontsize=20, weight="bold")
    pos = fig0_ax0.imshow(image, cmap='bone', interpolation='none', extent=[0, image.shape[1], 0, image.shape[0]])   

plt.savefig(os.path.join(save_folder, 'cell_PCA_log_effect.pdf'), format='pdf', dpi=600)

# %%
cell_PCA_folder = "cell/PCA_ptycho_recon"
cell_log_PCA_folder = "cell/log2_PCA_ptycho_recon"

fig0 = plt.figure(figsize=(13.5,5.5))
gs0 = gridspec.GridSpec(nrows=2, ncols=5, width_ratios=[1,1,1,1,1]) 
gs0.update(wspace=0.001, hspace=0.03)

nei_ls = ['nei3000', 'nei1000', 'nei300', 'nei100', 'nei30']
for i in range(5):
    src_folder = os.path.join(cell_PCA_folder, 'n2e7_'+nei_ls[i])
    image = dxchange.reader.read_tiff(os.path.join(src_folder, 'delta_ds_1.tiff'))
    image = image[:,:,0]
    fig0_ax0 = fig0.add_subplot(gs0[0,i])
    fig0_ax0.axis('off')
    if i == 0:
        fig0_ax0.text(-0.4, 0.5, 'PCA', transform=fig0_ax0.transAxes, color='#011FFF', fontsize=20, weight="bold")
        fig0_ax0.text(-0.5, 0.35, 'w/o ' + r'$log$', transform=fig0_ax0.transAxes, color='#011FFF', fontsize=20, weight="bold")
        fig0_ax0.text(0.03, 0.90, f"S'={nei_ls[i][3:]}", transform=fig0_ax0.transAxes, color='#F7FF0F', fontsize=16)
    else:
        fig0_ax0.text(0.03, 0.90, f"{nei_ls[i][3:]}", transform=fig0_ax0.transAxes, color='#F7FF0F', fontsize=16)
    pos = fig0_ax0.imshow(image, cmap='bone', interpolation='none', extent=[0, image.shape[1], 0, image.shape[0]])

for i in range(5):
    src_folder = os.path.join(cell_log_PCA_folder, 'n2e7_'+nei_ls[i])
    image = dxchange.reader.read_tiff(os.path.join(src_folder, 'delta_ds_1.tiff'))
    image = image[:,:,0]
    fig0_ax0 = fig0.add_subplot(gs0[1,i])
    fig0_ax0.axis('off')
    if i == 0:
        fig0_ax0.text(-0.4, 0.5, 'PCA', transform=fig0_ax0.transAxes, color='#FF0101', fontsize=20, weight="bold")
        fig0_ax0.text(-0.5, 0.35, 'with ' + r'$log$', transform=fig0_ax0.transAxes, color='#FF0101', fontsize=20, weight="bold")
    pos = fig0_ax0.imshow(image, cmap='bone', interpolation='none', extent=[0, image.shape[1], 0, image.shape[0]])    
   

plt.savefig(os.path.join(save_folder, 'cell_PCA_log_effect_v2.pdf'), format='pdf', dpi=600)

# %%
cell_NMF_folder = "cell/NMF_ptycho_recon"
cell_log_NMF_folder = "cell/log2_NMF_ptycho_recon"

fig0 = plt.figure(figsize=(13.5,13))
gs0 = gridspec.GridSpec(nrows=4, ncols=5, width_ratios=[5,5,0.5,5,5]) 
gs0.update(wspace=0.005, hspace=0.005)

nei_ls = ['nei4000', 'nei3000', 'nei2000', 'nei1000']
for i in range(4):
    src_folder = os.path.join(cell_NMF_folder, 'n2e7_'+nei_ls[i])
    image = dxchange.reader.read_tiff(os.path.join(src_folder, 'delta_ds_1.tiff'))
    image = image[:,:,0]
    fig0_ax0 = fig0.add_subplot(gs0[i,0])
    fig0_ax0.axis('off')
    if i == 0:
        fig0_ax0.text(0.35, 1.05, 'NMF', transform=fig0_ax0.transAxes, color='#27AE60', fontsize=20, weight="bold")
        fig0_ax0.text(0.03, 0.90, f"S'={nei_ls[i][3:]}", transform=fig0_ax0.transAxes, color='#F7FF0F', fontsize=16)
    else:
        fig0_ax0.text(0.03, 0.90, f"{nei_ls[i][3:]}", transform=fig0_ax0.transAxes, color='#F7FF0F', fontsize=16)
    pos = fig0_ax0.imshow(image, cmap='bone', interpolation='none', extent=[0, image.shape[1], 0, image.shape[0]])

for i in range(4):
    src_folder = os.path.join(cell_log_NMF_folder, 'n2e7_'+nei_ls[i])
    image = dxchange.reader.read_tiff(os.path.join(src_folder, 'delta_ds_1.tiff'))
    image = image[:,:,0]
    fig0_ax0 = fig0.add_subplot(gs0[i,1])
    fig0_ax0.axis('off')
    if i == 0:
        fig0_ax0.text(0.25, 1.05, 'log NMF', transform=fig0_ax0.transAxes, color='#F000FF', fontsize=20, weight="bold")
    pos = fig0_ax0.imshow(image, cmap='bone', interpolation='none', extent=[0, image.shape[1], 0, image.shape[0]])    
    
    
nei_ls = ['nei500', 'nei100', 'nei50', 'nei10']
for i in range(4):
    src_folder = os.path.join(cell_NMF_folder, 'n2e7_'+nei_ls[i])
    image = dxchange.reader.read_tiff(os.path.join(src_folder, 'delta_ds_1.tiff'))
    image = image[:,:,0]
    fig0_ax0 = fig0.add_subplot(gs0[i,3])
    fig0_ax0.axis('off')
    if i == 0:
        fig0_ax0.text(0.35, 1.05, 'NMF', transform=fig0_ax0.transAxes, color='#27AE60', fontsize=20, weight="bold")
        fig0_ax0.text(0.03, 0.90, f"S'={nei_ls[i][3:]}", transform=fig0_ax0.transAxes, color='#F7FF0F', fontsize=16)
    else:
        fig0_ax0.text(0.03, 0.90, f"{nei_ls[i][3:]}", transform=fig0_ax0.transAxes, color='#F7FF0F', fontsize=16)
    pos = fig0_ax0.imshow(image, cmap='bone', interpolation='none', extent=[0, image.shape[1], 0, image.shape[0]])
    
for i in range(4):
    src_folder = os.path.join(cell_log_NMF_folder, 'n2e7_'+nei_ls[i])
    image = dxchange.reader.read_tiff(os.path.join(src_folder, 'delta_ds_1.tiff'))
    image = image[:,:,0]
    fig0_ax0 = fig0.add_subplot(gs0[i,4])
    fig0_ax0.axis('off')
    if i == 0:
        fig0_ax0.text(0.25, 1.05, 'log NMF', transform=fig0_ax0.transAxes, color='#F000FF', fontsize=20, weight="bold")
    pos = fig0_ax0.imshow(image, cmap='bone', interpolation='none', extent=[0, image.shape[1], 0, image.shape[0]])
plt.savefig(os.path.join(save_folder, 'cell_NMF_log_effect.pdf'), format='pdf', dpi=600)

# %% [markdown]
# # Effect of NMF analysis on log(Intensity)

# %%
fig0 = plt.figure(figsize=(13.5,5.5))
gs0 = gridspec.GridSpec(nrows=2, ncols=5, width_ratios=[1,1,1,1,1]) 
gs0.update(wspace=0.001, hspace=0.03)


nei_ls = ['nei3000', 'nei1000', 'nei300', 'nei100', 'nei30']
for i in range(5):
    src_folder = os.path.join(cell_NMF_folder, 'n2e7_'+nei_ls[i])
    image = dxchange.reader.read_tiff(os.path.join(src_folder, 'delta_ds_1.tiff'))
    image = image[:,:,0]
    fig0_ax0 = fig0.add_subplot(gs0[0,i])
    fig0_ax0.axis('off')
    if i == 0:
        fig0_ax0.text(-0.4, 0.5, 'NMF', transform=fig0_ax0.transAxes, color='#27AE60', fontsize=20, weight="bold")
        fig0_ax0.text(-0.5, 0.35, 'w/o ' + r'$log$', transform=fig0_ax0.transAxes, color='#27AE60', fontsize=20, weight="bold")
        fig0_ax0.text(0.03, 0.90, f"S'={nei_ls[i][3:]}", transform=fig0_ax0.transAxes, color='#F7FF0F', fontsize=16)
    else:
        fig0_ax0.text(0.03, 0.90, f"{nei_ls[i][3:]}", transform=fig0_ax0.transAxes, color='#F7FF0F', fontsize=16)
    pos = fig0_ax0.imshow(image, cmap='bone', interpolation='none', extent=[0, image.shape[1], 0, image.shape[0]])

for i in range(5):
    src_folder = os.path.join(cell_log_NMF_folder, 'n2e7_'+nei_ls[i])
    image = dxchange.reader.read_tiff(os.path.join(src_folder, 'delta_ds_1.tiff'))
    image = image[:,:,0]
    fig0_ax0 = fig0.add_subplot(gs0[1,i])
    fig0_ax0.axis('off')
    if i == 0:
        fig0_ax0.text(-0.4, 0.5, 'NMF', transform=fig0_ax0.transAxes, color='#F000FF', fontsize=20, weight="bold")
        fig0_ax0.text(-0.5, 0.35, 'with ' + r'$log$', transform=fig0_ax0.transAxes, color='#F000FF', fontsize=20, weight="bold")
    pos = fig0_ax0.imshow(image, cmap='bone', interpolation='none', extent=[0, image.shape[1], 0, image.shape[0]])    
   

plt.savefig(os.path.join(save_folder, 'cell_NMF_log_effect_v2.pdf'), format='pdf', dpi=600)

# %% [markdown]
# # MSE of the compressed dataset

# %%
PCA_data_folder = "cell/PCA_compressed_data"
log_PCA_data_folder = "cell/log2_PCA_compressed_data"

NMF_data_folder = "cell/NMF_compressed_data"
log_NMF_data_folder = "cell/log2_NMF_compressed_data"

# %%
n_s_PCA = np.load(os.path.join(PCA_data_folder, "mse_dataset.npz"))["arr_0"]
dset_mse_PCA = np.load(os.path.join(PCA_data_folder, "mse_dataset.npz"))["arr_1"]

n_s_log_PCA = np.load(os.path.join(log_PCA_data_folder, "mse_dataset.npz"))["arr_0"]
dset_mse_log_PCA = np.load(os.path.join(log_PCA_data_folder, "mse_dataset.npz"))["arr_1"]

n_s_NMF = np.load(os.path.join(NMF_data_folder, "mse_dataset.npz"))["arr_0"]
dset_mse_NMF = np.load(os.path.join(NMF_data_folder, "mse_dataset.npz"))["arr_1"]

n_s_log_NMF = np.load(os.path.join(log_NMF_data_folder, "mse_dataset.npz"))["arr_0"]
dset_mse_log_NMF = np.load(os.path.join(log_NMF_data_folder, "mse_dataset.npz"))["arr_1"]

# %%
fig, ax = plt.subplots(figsize=(9.2,5), nrows=1, ncols=1)

ax.set_ylim(ymin=10**(-18), ymax=10**4)
ax.set_xscale('log')
ax.set_yscale('log')
# ax.set_yscale('symlog', linthresh=1e-12)
# ax.set_xticks(np.arange(0,5000,500))
ax.tick_params(axis='both', which='major', labelsize=18)
ax.tick_params(axis='both', which='minor', labelsize=18)
ax.set_xlabel("S'", fontsize=18)
ax.set_ylabel("dataset MSE", fontsize=18)
ax_plot = ax.plot(n_s_PCA, dset_mse_PCA, '-s', color='#011FFF', linewidth=2, markerfacecolor='none', markeredgecolor='#011FFF', markeredgewidth=2, alpha=0.5, label = 'PCA')
ax_plot = ax.plot(n_s_log_PCA, dset_mse_log_PCA, '-s', color='#FF0101', linewidth=2, markerfacecolor='none', markeredgecolor='#FF0101', markersize=6, markeredgewidth=2, alpha=0.5, label = 'log PCA')
ax_plot = ax.plot(n_s_NMF, dset_mse_NMF, '-o', color='#008E0D', linewidth=2, markerfacecolor='none', markeredgecolor='#008E0D', markeredgewidth=2, alpha=0.5, label = 'NMF')
ax_plot = ax.plot(n_s_log_NMF, dset_mse_log_NMF, '-o', color='#980CC1', linewidth=2, markerfacecolor='none', markeredgecolor='#980CC1', markeredgewidth=2, alpha=0.5, label = 'log NMF')

ax.legend(frameon=False, fontsize=18)
plt.savefig('dataset_MSE.pdf', format='pdf', dpi=600)

# %% [markdown]
#  # MSE of the recosntructed image

# %%
PCA_folder = "cell/PCA_ptycho_recon/comparison"
PCA_gt_folder = "cell/PCA_ptycho_recon/frc_gt"

log_PCA_folder = "cell/log2_PCA_ptycho_recon/comparison"
log_PCA_gt_folder = "cell/log2_PCA_ptycho_recon/frc_gt"

NMF_folder = "cell/NMF_ptycho_recon/comparison"
NMF_gt_folder = "cell/NMF_ptycho_recon/frc_gt"

log_NMF_folder = "cell/log2_NMF_ptycho_recon/comparison"
log_NMF_gt_folder = "cell/log2_NMF_ptycho_recon/frc_gt"

# %%
n_S_PCA = np.load(os.path.join(PCA_folder, "mse.npz"))["arr_0"]
mse_PCA = np.load(os.path.join(PCA_folder, "mse.npz"))["arr_1"]

n_S_log_PCA = np.load(os.path.join(log_PCA_folder, "mse.npz"))["arr_0"]
mse_log_PCA = np.load(os.path.join(log_PCA_folder, "mse.npz"))["arr_1"]

n_S_NMF = np.load(os.path.join(NMF_folder, "mse.npz"))["arr_0"]
mse_NMF = np.load(os.path.join(NMF_folder, "mse.npz"))["arr_1"]

n_S_log_NMF = np.load(os.path.join(log_NMF_folder, "mse.npz"))["arr_0"]
mse_log_NMF = np.load(os.path.join(log_NMF_folder, "mse.npz"))["arr_1"]

# %%
fig, ax = plt.subplots(figsize=(9,5), ncols=1, nrows=1)
ax.plot(n_S_PCA, mse_PCA,  '-s', color='#011FFF', linewidth=2, markerfacecolor='none', markeredgecolor='#011FFF', markeredgewidth=2, alpha=0.5, label = 'PCA')
ax.plot(n_S_log_PCA, mse_log_PCA,  '-s', color='#FF0101', linewidth=2, markerfacecolor='none', markeredgecolor='#FF0101', markersize=6, markeredgewidth=2, alpha=0.5, label = 'log PCA')

ax.plot(n_S_NMF, mse_NMF,  '-o', color='#27AE60', linewidth=2, markerfacecolor='none', markeredgecolor='#27AE60', markeredgewidth=2, alpha=0.5, label = 'NMF')
ax.plot(n_S_log_NMF, mse_log_NMF,  '-o', color='#F000FF', linewidth=2, markerfacecolor='none', markeredgecolor='#F000FF', markersize=6, markeredgewidth=2, alpha=0.5, label = 'log NMF')
ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlabel("S'", fontsize=18)
ax.set_ylabel("MSE", fontsize=18)

ax.tick_params(axis='both', which='major', labelsize=18)
ax.tick_params(axis='both', which='minor', labelsize=18)  
ax.legend(frameon=False, fontsize=18)
plt.savefig(os.path.join(save_folder, 'recon_mse.pdf'), format='pdf', dpi=600)

# %% [markdown]
# # FRC crossing : 1/2-bit

# %%
n_S_PCA = np.load(os.path.join(PCA_folder, "frc_PCAmode1_intersection.npz"))["arr_0"]
frc_PCA = np.load(os.path.join(PCA_folder, "frc_PCAmode1_intersection.npz"))["arr_1"]
frc_gt_PCA = np.load(os.path.join(PCA_gt_folder, "frc_PCAmode1_intersection.npz"))["arr_1"]

n_S_log_PCA = np.load(os.path.join(log_PCA_folder, "frc_PCAmode1_intersection.npz"))["arr_0"]
frc_log_PCA = np.load(os.path.join(log_PCA_folder, "frc_PCAmode1_intersection.npz"))["arr_1"]
frc_gt_log_PCA = np.load(os.path.join(log_PCA_gt_folder, "frc_PCAmode1_intersection.npz"))["arr_1"]

n_S_NMF = np.load(os.path.join(NMF_folder, "frc_PCAmode1_intersection.npz"))["arr_0"]
frc_NMF = np.load(os.path.join(NMF_folder, "frc_PCAmode1_intersection.npz"))["arr_1"]
frc_gt_NMF = np.load(os.path.join(NMF_gt_folder, "frc_PCAmode1_intersection.npz"))["arr_1"]

n_S_log_NMF = np.load(os.path.join(log_NMF_folder, "frc_PCAmode1_intersection.npz"))["arr_0"]
frc_log_NMF = np.load(os.path.join(log_NMF_folder, "frc_PCAmode1_intersection.npz"))["arr_1"]
frc_gt_log_NMF = np.load(os.path.join(log_NMF_gt_folder, "frc_PCAmode1_intersection.npz"))["arr_1"]

# %%
fig, ax = plt.subplots(figsize=(9,5), ncols=1, nrows=1)
ax.plot(n_S_PCA, frc_gt_PCA,  '-s', color='#011FFF', linewidth=2, markerfacecolor='none', markeredgecolor='#011FFF', markeredgewidth=2, alpha=0.5, label = 'PCA - GT')
ax.plot(n_S_log_PCA, frc_gt_log_PCA,  '-s', color='#FF0101', linewidth=2, markerfacecolor='none', markeredgecolor='#FF0101', markersize=6, markeredgewidth=2, alpha=0.5, label = 'log PCA - GT')

ax.plot(n_S_NMF, frc_gt_NMF,  '-o', color='#27AE60', linewidth=2, markerfacecolor='none', markeredgecolor='#27AE60', markeredgewidth=2, alpha=0.5, label = 'NMF - GT')
ax.plot(n_S_log_NMF, frc_gt_log_NMF,  '-o', color='#F000FF', linewidth=2, markerfacecolor='none', markeredgecolor='#F000FF', markersize=6, markeredgewidth=2, alpha=0.5, label = 'log NMF - GT')
ax.set_xscale("log")
# ax.set_yscale("log")
ax.set_ylim([0,1.1])
ax.set_xlabel("S'", fontsize=18)
ax.set_ylabel("FRC/half-bit crossing fraction", fontsize=18)


ax.tick_params(axis='both', which='major', labelsize=18)
ax.tick_params(axis='both', which='minor', labelsize=18)
ax.legend(frameon=False, fontsize=18)
plt.savefig(os.path.join(save_folder, 'recon_frc_gt.pdf'), format='pdf', dpi=600)

# %%
n_s_ls = [1, 10, 30, 50, 100, 300, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000]
PCA_AUC_gt_ls = []
log_PCA_AUC_gt_ls = []

NMF_AUC_gt_ls = []
log_NMF_AUC_gt_ls = []

for n1, n2 in zip(n_S_PCA, n_S_log_PCA):
    PCA_frc_gt_curve = np.load(os.path.join(PCA_gt_folder, f"frc_1_nei{n1}.npy"))
    max_AUC = PCA_frc_gt_curve.shape[0]
    PCA_AUC_gt_ls.append(100*np.sum(PCA_frc_gt_curve)/max_AUC)
    
    log_PCA_frc_gt_curve = np.load(os.path.join(log_PCA_gt_folder, f"frc_1_nei{n2}.npy"))
    log_PCA_AUC_gt_ls.append(100*np.sum(log_PCA_frc_gt_curve)/max_AUC)
    
    NMF_frc_gt_curve = np.load(os.path.join(NMF_gt_folder, f"frc_1_nei{n1}.npy"))
    max_AUC = NMF_frc_gt_curve.shape[0]
    NMF_AUC_gt_ls.append(100*np.sum(NMF_frc_gt_curve)/max_AUC)
    
    log_NMF_frc_gt_curve = np.load(os.path.join(log_NMF_gt_folder, f"frc_1_nei{n2}.npy"))
    log_NMF_AUC_gt_ls.append(100*np.sum(log_NMF_frc_gt_curve)/max_AUC)

# %%
fig, ax = plt.subplots(figsize=(9,5), ncols=1, nrows=1)
ax.plot(n_S_PCA, PCA_AUC_gt_ls,  '-s', color='#011FFF', linewidth=2, markerfacecolor='none', markeredgecolor='#011FFF', markeredgewidth=2, alpha=0.5, label = 'PCA - GT')
ax.plot(n_S_log_PCA, log_PCA_AUC_gt_ls,  '-s', color='#FF0101', linewidth=2, markerfacecolor='none', markeredgecolor='#FF0101', markersize=6, markeredgewidth=2, alpha=0.5, label = 'log PCA - GT')

ax.plot(n_S_NMF, NMF_AUC_gt_ls,  '-o', color='#27AE60', linewidth=2, markerfacecolor='none', markeredgecolor='#27AE60', markeredgewidth=2, alpha=0.5, label = 'NMF - GT')
ax.plot(n_S_log_NMF, log_NMF_AUC_gt_ls,  '-o', color='#F000FF', linewidth=2, markerfacecolor='none', markeredgecolor='#F000FF', markersize=6, markeredgewidth=2, alpha=0.5, label = 'log NMF - GT')
ax.set_xscale("log")
# ax.set_yscale("log")
ax.set_ylim([0,105])
ax.set_xlabel("S'", fontsize=18)
ax.set_ylabel("AUC (%)", fontsize=18)

ax.tick_params(axis='both', which='major', labelsize=18)
ax.tick_params(axis='both', which='minor', labelsize=18)
ax.legend(frameon=False, fontsize=18)
plt.savefig(os.path.join(save_folder, 'recon_frc_gt_AUC.pdf'), format='pdf', dpi=600)
